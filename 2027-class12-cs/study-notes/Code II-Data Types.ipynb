# %%
name = python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 name = python
#
# NameError: name 'python' is not defined

# %%
name = "python"
print(name)
# Out:
# python

# %%
txt = 12B
# Out:
#   Cell In[3], line 1
#     txt = 12B
#            ^
# SyntaxError: invalid decimal literal

# %%
txt = "12B"
print(txt)
# Out:
# 12B

# %%
date = 26-04-26
# Out:
#   Cell In[5], line 1
#     date = 26-04-26
#               ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
date = "26-04-26"
print(date)
# Out:
# 26-04-26

# %%
email=stanes@gmail.com
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 email=stanes@gmail.com
#
# NameError: name 'stanes' is not defined

# %%
email='stanes@gmail.com'
print(email)
# Out:
# stanes@gmail.com

# %%
d={1:10, 1:400}
print(d)
# Out:
# {1: 400}

# %%
d={1.0:10, 1:400}
print(d)
# Out:
# {1.0: 400}

# %%
dct={[1,2,3]:1000}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dct={[1,2,3]:1000}
#
# TypeError: unhashable type: 'list'

# %%
dct={(1,2,3):1000}
print(dct)
# Out:
# {(1, 2, 3): 1000}

# %%
a=None

# %%
print(a)
# Out:
# None

# %%
type(a)
# Out:
# NoneType

# %%
a
